# %%
from typing_extensions import TypedDict
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field
from langchain_tavily import TavilySearch

from dotenv import load_dotenv
from prompt import INDEPENDENT_AGENT_PROMPT, WORKER_PROMPT, QUERY_SPLITTER_PROMPT

import time

# %%
WEB_SEARCH_RELEVANCE_SCORE_THRESHOLD = 0.80

class IndependentAgentState(TypedDict):
    question: str
    model: ChatGoogleGenerativeAI
    depth: int
    breadth: int

class IndependentAgentOutput(BaseModel):
    sub_queries: list[str] = Field(
        description="List of sub-queries to be answered independently"
    )

class WorkerOutput(BaseModel):
    answer: str = Field(
        description="The answer to the question"
    )

class QuerySplitterOutput(BaseModel):
    can_split: bool = Field(
        description="Whether the query can be split into sub-queries"
    )

class WebSearchResult(BaseModel):
    cited_url: str = Field(description="The URL of the web page")
    content: str = Field(description="The content of the web page")
    score: float = Field(description="The relevance score of the web page")

# %%
def build_model(agentState):
    agentState['model'] = ChatGoogleGenerativeAI(model="gemini-2.5-pro")

def sleep_thread():
    sleep_time = 1
    print(f"Sleeping for {sleep_time} seconds to avoid rate limits...")
    time.sleep(sleep_time)
    print(f"Woke Up!")

# %%
def can_split_into_subtasks(query: str, model: ChatGoogleGenerativeAI) -> bool:
    """ Determine if the query can be split into sub-tasks """
    model_with_structured_output = model.with_structured_output(QuerySplitterOutput)
    query_splitter_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", QUERY_SPLITTER_PROMPT),
            ("human", "Query: \n\n {query}"),
        ]
    )

    query_splitter_retriever = query_splitter_prompt | model_with_structured_output
    query_splitter_response: QuerySplitterOutput = query_splitter_retriever.invoke({"query": query})
    sleep_thread()

    return query_splitter_response.can_split

# %%
def parse_web_search_results(web_search_result):
    search_results = []

    for result in web_search_result['results']:
        cited_url = result['url']
        search_content = result['content']
        search_score = result['score']

        if search_score >= WEB_SEARCH_RELEVANCE_SCORE_THRESHOLD:
            search_results.append(
                WebSearchResult(
                    cited_url=cited_url, content=search_content, score=search_score))
    
    return search_results

def web_search(query):
    print(f"\n Performing Web Search for {query} \n")

    web_search_tool = TavilySearch(max_results=5)
    web_results = web_search_tool.invoke({"query": query})

    return parse_web_search_results(web_results)

# %%
def supervisor(agentState: IndependentAgentState):
    query = agentState['question']
    model = agentState['model']
    current_depth = agentState['depth']
    print(f"Initiating Supervisor for '{query}'...")
    
    can_split = False
    if current_depth > 0:
        can_split = can_split_into_subtasks(query, model)
        print(f"Should agent split the query? => {can_split}")
    else:
        print(f"Depth Limit of {current_depth} reached")

    report = ""

    if can_split:
        report = independent_agent(agentState)
    else: 
        report = worker(query, model)
    
    return report


def independent_agent(agentState: IndependentAgentState):
    query = agentState['question']
    model = agentState['model']
    print(f"Initiating Independent Agent for '{query}'...")

    model_with_structured_output = model.with_structured_output(IndependentAgentOutput)
    independent_agent_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", INDEPENDENT_AGENT_PROMPT),
            ("human", "Query: \n\n {query} \n\n, Limit: {limit}"),
        ]
    )

    independent_agent_retriever = independent_agent_prompt | model_with_structured_output

    independent_sub_tasks: IndependentAgentOutput = independent_agent_retriever.invoke(
        { "query": query, "limit": agentState['breadth'] }
    )
    sleep_thread()

    research_reports = ["# Research Report"]

    current_depth: int = agentState['depth']

    for sub_query in independent_sub_tasks.sub_queries:
        supervisor_agent_state: IndependentAgentState = {
            'question': sub_query,
            'depth': current_depth - 1, # Reducing the depth for each sub-task
            'breadth': agentState['breadth'],
            'model': agentState['model'], 
        }
        supervisor_response = supervisor(supervisor_agent_state)

        research_reports.append(
            " \n ## " + sub_query + "\n\n" + supervisor_response)

    return '\n\n'.join(research_reports)


def worker(query: str, model: ChatGoogleGenerativeAI):
    """ A straight-forward worker that just answers the query """
    print(f"Researching for the Query => '{query}'...")
    web_search_results = web_search(query)
    print("Web Search completed!")

    model_with_structured_output = model.with_structured_output(WorkerOutput)
    worker_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", WORKER_PROMPT),
            ("human", "Query: \n\n {query} \n\n, Web Search Results: {web_search_results}"),
        ]
    )

    worker_retriever = worker_prompt | model_with_structured_output
    worker_result: WorkerOutput = worker_retriever.invoke({"query": query, "web_search_results": web_search_results})

    sleep_thread()
    print("Research Done!")

    return worker_result.answer

# %%
load_dotenv()  # Load environment variables from .env file

DEPTH = 2
BREADTH = 5

model = ChatGoogleGenerativeAI(model="gemini-2.5-pro")
response = supervisor({
    "model": model,
    "question": 'What are the investment philosophies of Duan Yongping, Warren Buffett, and Charlie Munger?',
    "depth": DEPTH,
    "breadth": BREADTH,
})
# Out:
# Initiating Supervisor for 'What are the investment philosophies of Duan Yongping, Warren Buffett, and Charlie Munger?'...
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Should agent split the query? => True
# Initiating Independent Agent for 'What are the investment philosophies of Duan Yongping, Warren Buffett, and Charlie Munger?'...
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Initiating Supervisor for 'What is the investment philosophy of Duan Yongping?'...
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Should agent split the query? => False
# Researching for the Query => 'What is the investment philosophy of Duan Yongping?'...
#
#  Performing Web Search for What is the investment philosophy of Duan Yongping?
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!
# Initiating Supervisor for 'What is the investment philosophy of Warren Buffett?'...
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Should agent split the query? => False
# Researching for the Query => 'What is the investment philosophy of Warren Buffett?'...
#
#  Performing Web Search for What is the investment philosophy of Warren Buffett?
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!
# Initiating Supervisor for 'What is the investment philosophy of Charlie Munger?'...
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Should agent split the query? => False
# Researching for the Query => 'What is the investment philosophy of Charlie Munger?'...
#
#  Performing Web Search for What is the investment philosophy of Charlie Munger?
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!
# Initiating Supervisor for 'What are the key similarities in the investment philosophies of Duan Yongping, Warren Buffett, and Charlie Munger?'...
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Should agent split the query? => True
# Initiating Independent Agent for 'What are the key similarities in the investment philosophies of Duan Yongping, Warren Buffett, and Charlie Munger?'...
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Initiating Supervisor for 'What are the core principles of Warren Buffett's value investing philosophy?'...
# Depth Limit of 0 reached
# Researching for the Query => 'What are the core principles of Warren Buffett's value investing philosophy?'...
#
#  Performing Web Search for What are the core principles of Warren Buffett's value investing philosophy?
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!
# Initiating Supervisor for 'What are the key tenets of Charlie Munger's investment philosophy and his concept of 'mental models'?'...
# Depth Limit of 0 reached
# Researching for the Query => 'What are the key tenets of Charlie Munger's investment philosophy and his concept of 'mental models'?'...
#
#  Performing Web Search for What are the key tenets of Charlie Munger's investment philosophy and his concept of 'mental models'?
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!
# Initiating Supervisor for 'What is Duan Yongping's investment philosophy and how has he publicly acknowledged the influence of Buffett and Munger?'...
# Depth Limit of 0 reached
# Researching for the Query => 'What is Duan Yongping's investment philosophy and how has he publicly acknowledged the influence of Buffett and Munger?'...
#
#  Performing Web Search for What is Duan Yongping's investment philosophy and how has he publicly acknowledged the influence of Buffett and Munger?
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!
# Initiating Supervisor for 'How do all three investors approach the concept of a 'circle of competence' and staying within it?'...
# Depth Limit of 0 reached
# Researching for the Query => 'How do all three investors approach the concept of a 'circle of competence' and staying within it?'...
#
#  Performing Web Search for How do all three investors approach the concept of a 'circle of competence' and staying within it?
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!
# Initiating Supervisor for 'What are the shared views of Buffett, Munger, and Duan Yongping on long-term holding, market fluctuations, and the importance of business quality over market timing?'...
# Depth Limit of 0 reached
# Researching for the Query => 'What are the shared views of Buffett, Munger, and Duan Yongping on long-term holding, market fluctuations, and the importance of business quality over market timing?'...
#
#  Performing Web Search for What are the shared views of Buffett, Munger, and Duan Yongping on long-term holding, market fluctuations, and the importance of business quality over market timing?
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!
# Initiating Supervisor for 'What are the main differences in the investment philosophies of Duan Yongping, Warren Buffett, and Charlie Munger?'...
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Should agent split the query? => True
# Initiating Independent Agent for 'What are the main differences in the investment philosophies of Duan Yongping, Warren Buffett, and Charlie Munger?'...
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Initiating Supervisor for 'What is the investment philosophy of Duan Yongping, including his concept of 'Benfen'?'...
# Depth Limit of 0 reached
# Researching for the Query => 'What is the investment philosophy of Duan Yongping, including his concept of 'Benfen'?'...
#
#  Performing Web Search for What is the investment philosophy of Duan Yongping, including his concept of 'Benfen'?
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!
# Initiating Supervisor for 'Describe Warren Buffett's investment philosophy, focusing on his principles of value investing, 'circle of competence', and economic moats.'...
# Depth Limit of 0 reached
# Researching for the Query => 'Describe Warren Buffett's investment philosophy, focusing on his principles of value investing, 'circle of competence', and economic moats.'...
#
#  Performing Web Search for Describe Warren Buffett's investment philosophy, focusing on his principles of value investing, 'circle of competence', and economic moats.
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!
# Initiating Supervisor for 'Explain Charlie Munger's investment philosophy, with an emphasis on his 'latticework of mental models' and psychological principles.'...
# Depth Limit of 0 reached
# Researching for the Query => 'Explain Charlie Munger's investment philosophy, with an emphasis on his 'latticework of mental models' and psychological principles.'...
#
#  Performing Web Search for Explain Charlie Munger's investment philosophy, with an emphasis on his 'latticework of mental models' and psychological principles.
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!
# Initiating Supervisor for 'What are the primary similarities and areas of overlap in the investment strategies of Duan Yongping, Warren Buffett, and Charlie Munger?'...
# Depth Limit of 0 reached
# Researching for the Query => 'What are the primary similarities and areas of overlap in the investment strategies of Duan Yongping, Warren Buffett, and Charlie Munger?'...
#
#  Performing Web Search for What are the primary similarities and areas of overlap in the investment strategies of Duan Yongping, Warren Buffett, and Charlie Munger?
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!
# Initiating Supervisor for 'What are the key differences in their investment approaches, particularly concerning their views on technology companies, portfolio concentration, and their respective primary markets?'...
# Depth Limit of 0 reached
# Researching for the Query => 'What are the key differences in their investment approaches, particularly concerning their views on technology companies, portfolio concentration, and their respective primary markets?'...
#
#  Performing Web Search for What are the key differences in their investment approaches, particularly concerning their views on technology companies, portfolio concentration, and their respective primary markets?
#
# Sleeping for 5 seconds to avoid rate limits...
# Woke Up!
# Research Done!

# %%
with open("research_output/output3.md", "w") as file_object:
    # Write the string to the file
    file_object.write(response)

# %%
research_file_outputs = []
for ind in range(100):
    research_output = {
        "id": ind + 1,
        "prompt": "",
        "article": "",
    }
    research_file_outputs.append(str(research_output))

research_file_outputs = '\n'.join(research_file_outputs)
research_file_outputs = research_file_outputs.replace("'", '"')

# %%
research_file_outputs
# Out:
# '{"id": 1, "prompt": "", "article": ""}\n{"id": 2, "prompt": "", "article": ""}\n{"id": 3, "prompt": "", "article": ""}\n{"id": 4, "prompt": "", "article": ""}\n{"id": 5, "prompt": "", "article": ""}\n{"id": 6, "prompt": "", "article": ""}\n{"id": 7, "prompt": "", "article": ""}\n{"id": 8, "prompt": "", "article": ""}\n{"id": 9, "prompt": "", "article": ""}\n{"id": 10, "prompt": "", "article": ""}\n{"id": 11, "prompt": "", "article": ""}\n{"id": 12, "prompt": "", "article": ""}\n{"id": 13, "prompt": "", "article": ""}\n{"id": 14, "prompt": "", "article": ""}\n{"id": 15, "prompt": "", "article": ""}\n{"id": 16, "prompt": "", "article": ""}\n{"id": 17, "prompt": "", "article": ""}\n{"id": 18, "prompt": "", "article": ""}\n{"id": 19, "prompt": "", "article": ""}\n{"id": 20, "prompt": "", "article": ""}\n{"id": 21, "prompt": "", "article": ""}\n{"id": 22, "prompt": "", "article": ""}\n{"id": 23, "prompt": "", "article": ""}\n{"id": 24, "prompt": "", "article": ""}\n{"id": 25, "prompt": "", "article": ""}\n{"id": 26, "prompt": "", "article": ""}\n{"id": 27, "prompt": "", "article": ""}\n{"id": 28, "prompt": "", "article": ""}\n{"id": 29, "prompt": "", "article": ""}\n{"id": 30, "prompt": "", "article": ""}\n{"id": 31, "prompt": "", "article": ""}\n{"id": 32, "prompt": "", "article": ""}\n{"id": 33, "prompt": "", "article": ""}\n{"id": 34, "prompt": "", "article": ""}\n{"id": 35, "prompt": "", "article": ""}\n{"id": 36, "prompt": "", "article": ""}\n{"id": 37, "prompt": "", "article": ""}\n{"id": 38, "prompt": "", "article": ""}\n{"id": 39, "prompt": "", "article": ""}\n{"id": 40, "prompt": "", "article": ""}\n{"id": 41, "prompt": "", "article": ""}\n{"id": 42, "prompt": "", "article": ""}\n{"id": 43, "prompt": "", "article": ""}\n{"id": 44, "prompt": "", "article": ""}\n{"id": 45, "prompt": "", "article": ""}\n{"id": 46, "prompt": "", "article": ""}\n{"id": 47, "prompt": "", "article": ""}\n{"id": 48, "prompt": "", "article": ""}\n{"id": 49, "prompt": "", "article": ""}\n{"id": 50, "prompt": "", "article": ""}\n{"id": 51, "prompt": "", "article": ""}\n{"id": 52, "prompt": "", "article": ""}\n{"id": 53, "prompt": "", "article": ""}\n{"id": 54, "prompt": "", "article": ""}\n{"id": 55, "prompt": "", "article": ""}\n{"id": 56, "prompt": "", "article": ""}\n{"id": 57, "prompt": "", "article": ""}\n{"id": 58, "prompt": "", "article": ""}\n{"id": 59, "prompt": "", "article": ""}\n{"id": 60, "prompt": "", "article": ""}\n{"id": 61, "prompt": "", "article": ""}\n{"id": 62, "prompt": "", "article": ""}\n{"id": 63, "prompt": "", "article": ""}\n{"id": 64, "prompt": "", "article": ""}\n{"id": 65, "prompt": "", "article": ""}\n{"id": 66, "prompt": "", "article": ""}\n{"id": 67, "prompt": "", "article": ""}\n{"id": 68, "prompt": "", "article": ""}\n{"id": 69, "prompt": "", "article": ""}\n{"id": 70, "prompt": "", "article": ""}\n{"id": 71, "prompt": "", "article": ""}\n{"id": 72, "prompt": "", "article": ""}\n{"id": 73, "prompt": "", "article": ""}\n{"id": 74, "prompt": "", "article": ""}\n{"id": 75, "prompt": "", "article": ""}\n{"id": 76, "prompt": "", "article": ""}\n{"id": 77, "prompt": "", "article": ""}\n{"id": 78, "prompt": "", "article": ""}\n{"id": 79, "prompt": "", "article": ""}\n{"id": 80, "prompt": "", "article": ""}\n{"id": 81, "prompt": "", "article": ""}\n{"id": 82, "prompt": "", "article": ""}\n{"id": 83, "prompt": "", "article": ""}\n{"id": 84, "prompt": "", "article": ""}\n{"id": 85, "prompt": "", "article": ""}\n{"id": 86, "prompt": "", "article": ""}\n{"id": 87, "prompt": "", "article": ""}\n{"id": 88, "prompt": "", "article": ""}\n{"id": 89, "prompt": "", "article": ""}\n{"id": 90, "prompt": "", "article": ""}\n{"id": 91, "prompt": "", "article": ""}\n{"id": 92, "prompt": "", "article": ""}\n{"id": 93, "prompt": "", "article": ""}\n{"id": 94, "prompt": "", "article": ""}\n{"id": 95, "prompt": "", "article": ""}\n{"id": 96, "prompt": "", "article": ""}\n{"id": 97, "prompt": "", "article": ""}\n{"id": 98, "prompt": "", "artic ...

# %%
with open("research_output/base_result.jsonl", "w") as file_object:
    # Write the string to the file
    file_object.write(research_file_outputs)
